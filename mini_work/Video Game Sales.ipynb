# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
csv_file_path = os.getenv('HOME')+'/aiffel/data_preprocess/data/vgsales.csv'

# %%
vgs = pd.read_csv(csv_file_path)
vgs
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
vgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
vgs[vgs.isnull().any(axis=1)]
# Out:
#         Rank                             Name Platform    Year         Genre  \
# 179      180                  Madden NFL 2004      PS2     NaN        Sports
# 377      378                 FIFA Soccer 2004      PS2     NaN        Sports
# 431      432       LEGO Batman: The Videogame      Wii     NaN        Action
# 470      471       wwe Smackdown vs. Raw 2006      PS2     NaN      Fighting
# 607      608                   Space Invaders     2600     NaN       Shooter
# ...      ...                              ...      ...     ...           ...
# 16427  16430                     Virtua Quest       GC     NaN  Role-Playing
# 16493  16496                       The Smurfs      3DS     NaN        Action
# 16494  16497  Legends of Oz: Dorothy's Return      3DS  2014.0        Puzzle
# 16543  16546           Driving Simulator 2011       PC  2011.0        Racing
# 16553  16556                   Bound By Flame     X360  2014.0  Role-Playing
#
# ...

# %%
len(vgs)-vgs.count()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
vgs.dropna(how='all', subset=['Year', 'Publisher'], inplace=True)
vgs = vgs.drop(columns='Publisher')

# %%
vgs[vgs['Year'].isnull()]
# Out:
#         Rank                         Name Platform  Year         Genre  \
# 179      180              Madden NFL 2004      PS2   NaN        Sports
# 377      378             FIFA Soccer 2004      PS2   NaN        Sports
# 431      432   LEGO Batman: The Videogame      Wii   NaN        Action
# 607      608               Space Invaders     2600   NaN       Shooter
# 624      625                    Rock Band     X360   NaN          Misc
# ...      ...                          ...      ...   ...           ...
# 16307  16310                Freaky Flyers       GC   NaN        Racing
# 16327  16330                    Inversion       PC   NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3   NaN     Adventure
# 16427  16430                 Virtua Quest       GC   NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS   NaN        Action
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# ...

# %%
vgs['Year'] = vgs['Year'].fillna(vgs['Year'].mean().round())

# %%
vgs.isnull().any()

# %%
vgs.duplicated().any()
# Out:
# False

# %%
plt.figure(figsize=(15,8))
plt.title('Sales count by genre', size=15)
sns.histplot(data=vgs, x='Genre', hue='Genre')
# Out:
# <AxesSubplot:title={'center':'Sales count by genre'}, xlabel='Genre', ylabel='Count'>

# %%
plt.figure(figsize=(15,8))
plt.title('Sales count by genre', size=15)
sns.barplot(data=vgs, x='Genre', y=)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_49/126122847.py in <module>
#       1 plt.figure(figsize=(15,8))
#       2 plt.title('Sales count by genre', size=15)
# ----> 3 sns.barplot(data=vgs, x='Genre')
#
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/conda/lib/python3.9/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
vgs.groupby('Genre').sum()[cols]
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action          877.57    524.92    159.50       187.35       1750.37
# Adventure       105.80     64.13     52.01        16.81        238.98
# Fighting        221.92    100.22     87.35        36.24        445.70
# Misc            410.23    215.98    107.72        75.32        809.90
# Platform        447.05    201.15    130.77        51.59        830.89
# Puzzle          123.78     50.78     57.31        12.55        244.95
# Racing          359.42    238.39     56.69        77.27        732.04
# Role-Playing    327.28    188.06    352.26        59.61        927.32
# Shooter         582.59    313.24     38.28       102.69       1037.32
# Simulation      183.31    113.38     63.64        31.52        392.14
# Sports          682.54    376.30    135.25       134.87       1329.35
# Strategy         68.70     45.33     49.34        11.36        174.99
